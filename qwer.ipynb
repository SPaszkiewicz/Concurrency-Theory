[21, 22, 21, 22, 22, 21],
[21, 21, 22, 22, 22, 21],
[21, 22, 21, 22, 22, 21],
[21, 22, 22, 21, 22, 22],
[18, 19, 18, 19, 19, 18],
[18, 19, 19, 18, 19, 18],
[18, 19, 18, 19, 18, 19],
[18, 19, 18, 19, 18, 19],
[18, 19, 18, 19, 18, 19],
[18, 19, 18, 19, 19, 18],
[18, 19, 19, 18, 19, 18],
[18, 19, 19, 18, 19, 18],
[18, 19, 19, 19, 18, 19]]

time_stamps = [1, 2, 5, 7, 10, 20]
# Out:
# 81

# %%
import csv
with open('result_4cons.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=',',
                        quotechar=',', quoting=csv.QUOTE_MINIMAL)    
    writer.writerow(time_stamps)
    for row in data_4_cons:
        print(list(map(lambda x: str(x), row)))
        writer.writerow(list(map(lambda x: str(x), row)))

with open('result_3locks.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=',',
                        quotechar=',', quoting=csv.QUOTE_MINIMAL)    
    writer.writerow(time_stamps)
    for row in data_3_lock:
        print(list(map(lambda x: str(x), row)))
        writer.writerow(list(map(lambda x: str(x), row)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fd476b30ad00> in <module>
#       4                         quotechar=',', quoting=csv.QUOTE_MINIMAL)
#       5     writer.writerow(time_stamps)
# ----> 6     for row in data_4_cons:
#       7         print(list(map(lambda x: str(x), row)))
#       8         writer.writerow(list(map(lambda x: str(x), row)))
#
# NameError: name 'data_4_cons' is not defined

# %%
avg_sync = np.mean(data_sync, axis=1)
print(avg_sync)
avg_async = np.mean(data_async, axis=1)
avg_async
# Out:
# [130.33333333 130.16666667 130.16666667 130.33333333 130.33333333
#  130.16666667 130.         130.16666667 128.83333333  65.
#   65.16666667  65.16666667  65.5         65.33333333  65.33333333
#   65.16666667  65.33333333  65.33333333  63.83333333  64.33333333
#   63.66666667  64.16666667  63.5         63.83333333  64.
#   64.          64.16666667  32.66666667  32.66666667  32.5
#   32.66666667  32.66666667  32.5         32.5         32.5
#   32.66666667  32.16666667  32.          32.33333333  32.33333333
#   32.33333333  32.33333333  32.5         32.33333333  32.16666667
#   26.          26.          26.          26.          26.
#   26.16666667  26.          25.83333333  26.          21.66666667
#   21.83333333  21.83333333  21.66666667  21.83333333  21.66666667
#   21.83333333  21.83333333  21.66666667  21.5         21.5
#   21.5         21.5         21.5         21.5         21.5
#   21.5         21.66666667  18.5         18.5         18.5
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt


import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.set_size_inches(19.5, 10.5)
# [100, 90, 80, 70, 60, 50, 30, 20, 10]
X = np.array([10, 20, 30, 50, 60, 70, 80, 90, 100])
Y = np.array([10, 20, 30, 50, 60, 70, 80, 90, 100])
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
#Z = np.matrix([[avg_async[i*9 + j] for j in range(8, -1, -1)] for i in range(9)])
W = np.flip(avg_sync, 0)
Z = np.matrix([[W[i*9 + j] for j in range(9)] for i in range(8, -1, -1)])
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.view_init(30, 60)

# Customize the z axis.
ax.set_zlim(10, 130)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter('{x:.02f}')
ax.set_ylabel("Czas operacji na buforze [ms]")
ax.set_ylabel("Czas oczekiwnia producenta lub konsumenta [ms]")
ax.set_zlabel("Ilość wykonanych operacji")

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.set_size_inches(19.5, 10.5)
# [100, 90, 80, 70, 60, 50, 30, 20, 10]
X = np.array([10, 20, 30, 50, 60, 70, 80, 90, 100])
Y = np.array([10, 20, 30, 50, 60, 70, 80, 90, 100])
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
#Z = np.matrix([[avg_async[i*9 + j] for j in range(8, -1, -1)] for i in range(9)])
Z = np.matrix([[avg_async[i*9 + j] for j in range(9)] for i in range(9)])

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.view_init(30, 60)


# Customize the z axis.
ax.set_zlim(10, 130)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter('{x:.02f}')
ax.set_ylabel("Czas operacji na buforze [ms]")
ax.set_xlabel("Czas oczekiwnia producenta lub konsumenta [ms]")
ax.set_zlabel("Ilość wykonanych operacji")

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
fig.set_size_inches(19.5, 10.5)
# [100, 90, 80, 70, 60, 50, 30, 20, 10]
X = np.array([10, 20, 30, 50, 60, 70, 80, 90, 100])
Y = np.array([10, 20, 30, 50, 60, 70, 80, 90, 100])
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
#Z = np.matrix([[avg_async[i*9 + j] for j in range(8, -1, -1)] for i in range(9)])
Z = np.matrix([[avg_sync[i*9 + j] - avg_async[i*9 + j] for j in range(9)] for i in range(9)])

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.view_init(30, 60)


# Customize the z axis.
ax.set_zlim(10, 130)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter('{x:.02f}')
ax.set_ylabel("Czas operacji na buforze [ms]")
ax.set_xlabel("Czas oczekiwnia producenta lub konsumenta [ms]")
ax.set_zlabel("Ilość wykonanych operacji")

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
# std_values_3_locks = list(map(lambda x: round(x, 2), np.std(data_3_lock, axis=0)))
# print(std_values_3_locks)
# std_values_4_cons = list(map(lambda x: round(x, 2), np.std(data_4_cons, axis=0)))
# print(std_values_4_cons)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-390c8b87e6cc> in <module>
# ----> 1 std_values_3_locks = list(map(lambda x: round(x, 2), np.std(data_3_lock, axis=0)))
#       2 print(std_values_3_locks)
#       3 std_values_4_cons = list(map(lambda x: round(x, 2), np.std(data_4_cons, axis=0)))
#       4 print(std_values_4_cons)
#
# NameError: name 'data_3_lock' is not defined

# %%
# np.array(avg_values_3_locks)/np.array(avg_values_4_cons)
# Out:
# array([2.52594857, 2.57791548, 2.47809289, 2.35453783, 2.53970875,
#        2.46987705])

# %%
# plt.figure(figsize=(10, 7), dpi=80)
# plt.plot(time_stamps, avg_values_3_locks, 'go--', label='Algorytm na 3 lockach')
# plt.plot(time_stamps, avg_values_4_cons, 'ro--', label='Algorytm na 4 conditionach')
# plt.errorbar(time_stamps, avg_values_4_cons, std_values_4_cons, linestyle='None', fmt='ro', linewidth=0.75)
# plt.errorbar(time_stamps, avg_values_3_locks, std_values_3_locks, linestyle='None', fmt='go', linewidth=0.75)
# plt.ylabel('Ilość wykonanych operacji')
# plt.xlabel('Czas wykonania w sekundach [s]')
# plt.legend()
